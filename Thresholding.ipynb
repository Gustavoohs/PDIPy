# %%
# Bibliotecas
import matplotlib.pyplot as plt
import tifffile as tif
from skimage.filters import try_all_threshold

# %%
# Leitura da imagem
img = tif.imread('L71221071_07120010720_DN_B4.tif')

# Cálculo do thresholding
fig, ax = try_all_threshold(img, figsize=(12, 8), verbose=False)
plt.show()

# %%
# Leitura da imagem
img = tif.imread('/content/drive/MyDrive/Curso PDI com Python/L71221071_07120010720_DN_B4.tif')

# Cálculo do thresholding
'''thresh = threshold_local(img, 999)
bin1 = img > thresh 
bin2 = img < thresh'''
# Out:
# 'thresh = threshold_local(img, 999)\nbin1 = img > thresh \nbin2 = img < thresh'

# %%
# Visualizando threshold
plt.figure(figsize=(12,8))
plt.imshow(thresh, cmap="gray")
plt.show()

# %%
# Visualizando resultado em imagem
fig, ax = plt.subplots(1,2, figsize=(12, 8))
ax[0].imshow(img, cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')
ax[1].imshow(bin1, cmap=plt.cm.gray)
ax[1].set_title('Threshold menor')
ax[1].axis('off')
plt.show()

# %%
# Visualizando resultado em imagem
fig, ax = plt.subplots(1,2, figsize=(12, 8))
ax[0].imshow(img, cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')
ax[1].imshow(bin2, cmap=plt.cm.gray)
ax[1].set_title('Threshold maior')
ax[1].axis('off')
plt.show()

# %%
# !pip install -q rasterio lazypredict

# %%
# Bibliotecas
import numpy as np
import matplotlib.pyplot as plt
import rasterio as rio
from rasterio.plot import reshape_as_image
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier, LazyRegressor

# %%
# Lendo imagem como array
src = rio.open('/content/drive/MyDrive/Curso PDI com Python/L71221071_07120010720_DN.tif')
array = src.read()
img = reshape_as_image(array)

# %%
# Lendo classes
with rio.open('/content/roi.tif') as src2:
  roi = src2.read(1)

# %%
# Criando conjunto de treino
X = img[roi > 0]
y  = roi[roi > 0]

# %%
# Dividindo conjunto em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# Rodando o Lazy
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:03<00:00,  8.79it/s]

# %%
# Visualizando resultado
models
# Out:
#                                Accuracy  Balanced Accuracy  F1 Score  \
# Model
# LabelPropagation                   0.99               0.99      0.99
# LabelSpreading                     0.99               0.99      0.99
# ExtraTreesClassifier               0.99               0.99      0.99
# LinearDiscriminantAnalysis         0.98               0.99      0.98
# SVC                                0.99               0.98      0.99
# KNeighborsClassifier               0.99               0.98      0.99
# DecisionTreeClassifier             0.99               0.98      0.99
# LGBMClassifier                     0.99               0.98      0.99
# LinearSVC                          0.98               0.98      0.98
# LogisticRegression                 0.98               0.98      0.98
# BaggingClassifier                  0.98               0.98      0.98
# RandomForestClassifier             0.99               0.97      0.99
# GaussianNB                         0.99               0.97      0.99
# NearestCentroid                    0.98               0.97      0.98
# QuadraticDiscriminantAnalysis      0.98               0.97      0.98
# CalibratedClassifierCV             0.97               0.97      0.97
# PassiveAggressiveClassifier        0.96               0.95      0.95
# SGDClassifier                      0.89               0.95      0.90
# ExtraTreeClassifier                0.94               0.89      0.94
# RidgeClassifierCV                  0.87               0.88      0.85
# Perceptron                         0.90               0.87      0.87
# BernoulliNB                        0.88               0.87      0.87
# RidgeClassifier                    0.84               0.85      0.79
# AdaBoostClassifier                 0.65               0.50      0.54
# DummyClassifier                    0.34               0.17      0.17
#
#                                Time Taken
# Model
# LabelPropagation                     0.15
# LabelSpreading                       0.14
# ExtraTreesClassifier                 0.32
# LinearDiscriminantAnalysis           0.05
# SVC                                  0.13
# KNeighborsClassifier                 0.41
# DecisionTreeClassifier               0.05
# LGBMClassifier                       0.30
# LinearSVC                            0.05
# LogisticRegression                   0.06
# BaggingClassifier                    0.07
# RandomForestClassifier               0.37
# GaussianNB                           0.04
# NearestCentroid                      0.11
# QuadraticDiscriminantAnalysis        0.05
# CalibratedClassifierCV               0.18
# PassiveAggressiveClassifier          0.04
# SGDClassifier                        0.07
# ExtraTreeClassifier                  0.03
# RidgeClassifierCV                    0.05
# Perceptron                           0.05
# BernoulliNB                          0.04
# RidgeClassifier                      0.07
# AdaBoostClassifier                   0.30
# DummyClassifier                      0.03

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15,10)

# %%
# Bibliotecas
from rsgislib import imagecalibration
from spectral import imshow
import numpy as np
import tifffile as tif

# %%
# Calculando DOS
imagecalibration.performDOSCalc('D:/L5_TOA.tif', 'D:/L5_DOS.tif',gdalformat='GTiff')

# %%
# Lendo resultado
imgTOA = tif.imread('D:/L5_TOA.tif')
imgDOS = tif.imread('D:/L5_DOS.tif')

# %%
# Visualizando imagem TOA
imshow(imgTOA, (2,3,1), stretch=(0.02))
# Out:
# ImageView object:
#   Display bands       :  (2, 3, 1)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 47.0]
#     G: [0.0, 64.0]
#     B: [0.0, 35.0]

# %%
# Visualizando DOS
imshow(imgDOS, (2,3,1), stretch=(0.02))
# Out:
# ImageView object:
#   Display bands       :  (2, 3, 1)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 33.0]
#     G: [0.0, 39.0]
#     B: [0.0, 18.0]

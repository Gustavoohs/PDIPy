# %%
# !pip install spectral
# Out:
# Collecting spectral
#   Downloading https://files.pythonhosted.org/packages/4f/9b/db2e160f891441b2f576e31caaa93c283ce5f82d625173830abd7ab3cbc3/spectral-0.22.2.tar.gz (184kB)
#      |████████████████████████████████| 184kB 5.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from spectral) (1.19.5)
# Building wheels for collected packages: spectral
#   Building wheel for spectral (setup.py) ... done
#   Created wheel for spectral: filename=spectral-0.22.2-cp37-none-any.whl size=212955 sha256=50579e6335a97d46339a0fd3c32dd25c4f5938ab9227c85a491c846849ff090b
#   Stored in directory: /root/.cache/pip/wheels/fb/00/da/ac778d1ab6e196cb7f56d104d4dfdfc0aad4e2b208275c0726
# Successfully built spectral
# Installing collected packages: spectral
# Successfully installed spectral-0.22.2

# %%
from spectral import *
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams['figure.figsize'] = (15,10)

# %%
img = envi.open('sja3.hdr','sja3.rfl')

# %%
(m, c) = kmeans(img, 5, 10)
# Out:
# Iteration 1...314315 pixels reassigned.
# Iteration 2...19104 pixels reassigned.
# Iteration 3...31431 pixels reassigned.
# Iteration 4...29684 pixels reassigned.
# Iteration 5...19964 pixels reassigned.
# Iteration 6...16059 pixels reassigned.
# Iteration 7...12984 pixels reassigned.
# Iteration 8...9633 pixels reassigned.
# Iteration 9...7250 pixels reassigned.
# Iteration 10...6719 pixels reassigned.
# spectral:INFO: kmeans terminated with 5 clusters after 10 iterations
# INFO:spectral:kmeans terminated with 5 clusters after 10 iterations

# %%
plt.imshow(m, cmap='jet')

# %%
plt.figure()

for i in range(c.shape[0]):
  plt.plot(c[i])
 

plt.grid()

# %%
+

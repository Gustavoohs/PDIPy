# %%
# !pip install fuzzy-c-means rasterio -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 39.6 MB/s eta 0:00:00

# %%
# Bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from fcmeans import FCM
from rasterio.plot import reshape_as_image
import rasterio as rio

# %%
# Lendo imagem
with rio.open('/content/drive/MyDrive/Curso PDI com Python/L71221071_07120010720_DN.tif') as src:
  meta = src.meta
  img = reshape_as_image(src.read())

# %%
# Reformatando dimensões
X = img.reshape(img.shape[0]*img.shape[1], img.shape[2])

# %%
# Instanciando modelo
fcm = FCM(n_clusters=6)
fcm.fit(X)

# %%
# Rodando na imagem
fcm_labels = fcm.predict(X)

# %%
# Reformatando dimensões
result = fcm_labels.reshape(img.shape[0], img.shape[1])

# %%
# Visualizando resultado
plt.imshow(result)
